# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthikorumilli/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Mod8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-14 07:00:22--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  92.9MB/s    in 0.7s
#
# 2023-05-14 07:00:28 (92.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19803   1207.4114v1  We present metrics for measuring the similarit...    cs
# 36969  1601.02197v1  In this paper, we investigate stable patterns ...    cs
# 11726  1610.07379v1  We present a new algorithm, truncated variance...  stat
# 11710  1610.04019v1  We propose a flexible framework for spectral c...  stat
# 7697   1802.09031v1  Residual Networks (ResNets) have become state-...  stat
# ...             ...                                                ...   ...
# 16420  1702.04066v1  We present a new parallel corpus, JHU FLuency-...    cs
# 12698   1311.1406v1  We propose a novel topic discovery algorithm f...    cs
# 35813   1301.0594v1  We develop a model of how information flows in...    cs
# 21850   1401.3291v2  In this work we consider the problem of detect...  stat
# 32411  1612.01401v2  Deep neural networks (DNNs) have proven to be ...    cs
#
#                                                    title  year  \
# 19803       Metrics for Finite Markov Decision Processes  2012
# 36969  Identifying Stable Patterns over Time for Emot...  2016
# 11726  Truncated Variance Reduction: A Unified Approa...  2016
# 11710  Voice Conversion from Non-parallel Corpora Usi...  2016
# 7697   Functional Gradient Boosting based on Residual...  2018
# ...                                                  ...   ...
# 16420  JFLEG: A Fluency Corpus and Benchmark for Gram...  2017
# 12698  TOP-SPIN: TOPic discovery via Sparse Principal...  2013
# 35813  Modelling Information Incorporation in Markets...  2012
# 21850  Detection of Anomalous Crowd Behavior Using Sp...  2014
# 32411  Learning Adversary-Resistant Deep Neural Networks  2016
#
#                                                 keywords
# 19803  [measuring, similarity, formulation, bisimulat...
# 36969  [investigate, electroencephalogram, recognitio...
# 11726  [algorithm, truncated, reduction, optimization...
# 11710  [framework, conversion, facilitates, unaligned...
# 7697   [theoretical, understanding, attractive, viewp...
# ...                                                  ...
# 16420  [developing, evaluating, grammatical, correcti...
# 12698  [discovery, algorithm, unlabeled, framework, d...
# 35813  [information, algorithms, automatically, detec...
# 21850  [detecting, anomalous, normative, multiframe, ...
# 32411  [effective, autonomous, performance, applicati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19803    [measuring, similarity, formulation, bisimulat...
# 36969    [investigate, electroencephalogram, recognitio...
# 11726    [algorithm, truncated, reduction, optimization...
# 11710    [framework, conversion, facilitates, unaligned...
# 7697     [theoretical, understanding, attractive, viewp...
#                                ...
# 10484    [successfully, different, engineering, procedu...
# 34632    [recognition, statistical, generalization, cap...
# 7710     [generalization, adversarial, framework, under...
# 13624    [associative, structures, clustered, introduce...
# 11364    [explosion, techniques, indispensable, routine...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8879 words.
# Out of those 4579 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ae0210e0-8e22-4571-8ea1-4cd2f0312bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae0210e0-8e22-4571-8ea1-4cd2f0312bb3")) {                    Plotly.newPlot(                        "ae0210e0-8e22-4571-8ea1-4cd2f0312bb3",                        [{"x":["similarity","distances","processes","aggregate","measuring","formulation","structure","reinforcement","discounted","bisimulation","approximators","extraction","smoothing","identifying","responses","consistency","electroencephalogram","developed","activated","associated","recognition","relatively","classification","investigated","systematically","efficiency","performance","stability","algorithms","different","investigate","significant","selection","experimental","incorporate","important","strengthen","heteroscedastic","variances","effective","estimation","demonstrate","including","algorithm","pointwise","typically","truncated","reduction","confidence","synthetic","theoretical","potential","effectiveness","optimization","guarantee","variational","framework","independent","unavailability","designated","requirements","conversion","representations","functions","comprises","reconstruct","practical","alignments","frameworks","applications","evaluations","objective","subjective","synthesizing","facilitates","correspondence","requirement","unaligned","construct","understanding","formalize","splitting","technique","functional","gradients","mathematically","attractive","viewpoint","leveraging","perspective","generalization","optimizing","combining","perception","guarantees","methodology","divergence","variables","relationships","explicitly","combination","propagation","distributions","illustrated","approximate","forecasting","observations","dynamically","developments","described","parameters","discussed","procedure","explanatory","necessarily","approximation","scenarios","application","considering","behavioral","decisions","propositions","propositional","membership","interpretable","interpretations","vehicular","multivalued","observables","possibilities","naturally","eigenvectors","processing","classical","braitenberg","represented","eigenvalues","operators","adjacency","consistent","blockmodel","simulated","geometric","overlapping","knowledge","stochastic","clustering","properties","logarithmic","communities","resulting","transform","incorporation","fundamental","challenging","inherently","representation","representative","granularities","vocabulary","inferring","information","nonparametric","congressional","retrieval","multilingual","introduced","evolution","deceptive","iterations","collaborations","parasites","evolutionary","additionally","evaluation","exponentially","symbiotic","magnitude","integration","techniques","automatically","principles","contributions","references","university","automatic","describes","literature","detection","evaluating","reciprocal","particular","citations","scientists","collaborate","advantage","introduces","phenomena","paraphrases","collaborative"],"y":[158,38,100,18,36,80,333,105,7,3,2,141,18,78,23,68,3,191,3,101,391,61,496,45,19,156,888,48,612,719,142,220,157,407,51,379,4,1,6,258,192,578,250,774,0,97,17,102,41,140,195,157,219,300,33,60,523,140,1,5,51,15,241,223,14,28,133,10,22,420,47,161,21,7,18,30,24,1,75,163,11,15,246,56,32,12,25,37,46,66,121,35,98,41,70,67,31,140,80,59,136,63,138,26,113,13,83,28,17,67,233,56,124,4,20,121,89,235,64,17,62,7,23,16,28,13,2,2,1,17,56,7,284,114,2,89,7,44,7,99,2,59,65,23,347,111,145,210,21,11,166,63,11,69,258,21,375,38,2,32,29,728,18,1,131,24,119,60,5,38,2,1,65,63,252,19,2,64,54,360,150,42,49,12,16,180,76,113,324,58,3,270,5,8,4,82,68,21,3,36],"type":"bar"},{"x":["similarity","distances","processes","aggregate","measuring","formul ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4579,), (4579, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Depth</span> <span style=''>of</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Theoretical</span> <span style=''>View</span> <br/><br/><span style=''>People</span> <span style=''>believe</span> <span style=''>that</span> <span style=''>depth</span> <span style=''>plays</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>role</span> <span style=''>in</span> <span style=''>success</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DNN)</span> <span style=''>However</span> <span style=''>this</span> <span style=''>belief</span> <span style=''>lacks</span> <span style=''>solid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>justifications</span> <span style=''>as</span> <span style=''>far</span> <span style=''>as</span> <span style=''>we</span> <span style=''>know</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>role</span> <span style=''>of</span> <span style=''>depth</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>of</span> <span style=''>margin</span> <span style=''>bound</span> <span style=''>In</span> <span style=''>margin</span> <span style=''>bound</span> <span style=''>expected</span> <span style=''>error</span> <span style=''>is</span> <span style=''>upper</span> <span style=''>bounded</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>margin</span> <span style=''>error</span> <span style=''>plus</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>Rademacher</span> <span style=''>Average</span> <span style=''>(RA)</span> <span style=''>based</span> <span style=''>capacity</span> <span style=''>term</span> <span style=''>First</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>RA</span> <span style=''>of</span> <span style=''>DNN</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increases</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>depth</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3548387096774193);'>indicates</span> <span style=''>negative</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>depth</span> <span style=''>on</span> <span style=''>test</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>deeper</span> <span style=''>networks</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>have</span> <span style=''>larger</span> <span style='background-color:rgba(0, 255, 0, 0.35623869801084984);'>representation</span> <span style=''>power</span> <span style=''>(measured</span> <span style=''>by</span> <span style=''>Betti</span> <span style=''>numbers</span> <span style=''>based</span> <span style=''>complexity)</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>shallower</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>class</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>thus</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style=''>Lp</span> <span style=''>Norm</span> <span style=''>Multiple</span> <span style=''>Kernel</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>derive</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>ell</span> <span style=''>p</span> <span style=''>norm</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>which</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>tighter</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>bound</span> <span style=''>than</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>Previous</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>aimed</span> <span style=''>at</span> <span style=''>analyzed</span> <span style=''>the</span> <span style=''>case</span> <span style=''>p1</span> <span style=''>only</span> <span style=''>while</span> <span style=''>our</span> <span style=''>analysis</span> <span style=''>covers</span> <span style=''>all</span> <span style=''>cases</span> <span style=''>1leq</span> <span style=''>pleqinfty</span> <span style=''>assuming</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>feature</span> <span style=''>mappings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>kernels</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncorrelated</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>that</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <span style=''>bound</span> <span style=''>is</span> <span style=''>tight</span> <span style=''>and</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consequences</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>excess</span> <span style=''>loss</span> <span style=''>namely</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>the</span> <span style=''>order</span> <span style=''>O(n</span> <span style=''>fracalpha1alpha)</span> <span style=''>where</span> <span style=''>alpha</span> <span style=''>is</span> <span style=''>the</span> <span style=''>minimum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvalue</span> <span style=''>decay</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>kernels</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>EigenGP</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Eigenfunctions</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.7230769230769232);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.35623869801084984);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>GP</span> <span style='background-color:rgba(255, 0, 0, 0.3199329983249581);'>inference</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>for</span> <span style=''>big</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>EigenGP</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>both</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>elements</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>eigenfunctions</span> <span style=''>of</span> <span style=''>a</span> <span style=''>GP</span> <span style=''>prior</span> <span style=''>and</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>precisions</span> <span style=''>in</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>finite</span> <span style=''>model</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>among</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orthogonal</span> <span style=''>basis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>eigenfunctions</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>most</span> <span style=''>compact</span> <span style='background-color:rgba(0, 255, 0, 0.35623869801084984);'>representation</span> <span style=''>Unlike</span> <span style=''>other</span> <span style=''>sparse</span> <span style=''>Bayesian</span> <span style=''>finite</span> <span style=''>models</span> <span style=''>where</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>function</span> <span style=''>has</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>form</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>eigenfunctions</span> <span style=''>live</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5925925925925928);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>as</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3203883495145632);'>combination</span> <span style=''>of</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>We</span> <span style=''>learn</span> <span style=''>the</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Tournament</span> <span style=''>Leave</span> <span style=''>pair</span> <span style=''>out</span> <span style=''>Cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>for</span> <span style=''>Receiver</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Operating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Characteristic</span> <span style=''>(ROC)</span> <span style=''>Analysis</span> <br/><br/><span style=''>Receiver</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristic</span> <span style=''>(ROC)</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>systems</span> <span style=''>Recent</span> <span style=''>studies</span> <span style=''>have</span> <span style=''>shown</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>an</span> <span style=''>area</span> <span style=''>under</span> <span style=''>ROC</span> <span style=''>curve</span> <span style=''>(AUC)</span> <span style=''>with</span> <span style=''>standard</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>methods</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>bias</span> <span style=''>The</span> <span style=''>leave</span> <span style=''>pair</span> <span style=''>out</span> <span style=''>(LPO)</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>correct</span> <span style=''>this</span> <span style=''>bias</span> <span style=''>However</span> <span style=''>while</span> <span style=''>LPO</span> <span style=''>produces</span> <span style=''>an</span> <span style=''>almost</span> <span style=''>unbiased</span> <span style=''>estimate</span> <span style=''>of</span> <span style=''>AUC</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>ranking</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>needed</span> <span style=''>for</span> <span style=''>plotting</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>ROC</span> <span style=''>curve</span> <span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tournament</span> <span style=''>leave</span> <span style=''>pair</span> <span style=''>out</span> <span style=''>(TLPO)</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>This</span> <span style=''>method</span> <span style=''>extends</span> <span style=''>LPO</span> <span style=''>by</span> <span style=''>creating</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tournament</span> <span style=''>from</span> <span style=''>pair</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>a</span> <span style=''>ranking</span> <span style=''>for</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10190168640114819)
# 	representation (0.13455328310010764)
# 	knowledge (0.12450663796196627)
# 	segmentation (0.07355579476139218)
# 	detection (0.116254036598493)
# 	experimental (0.1460351632579835)
# 	different (0.25798349479727306)
# 	information (0.26121277359167566)
# 	convolutional (0.13060638679583783)
# 	recognition (0.14029422317904558)
#
# Some Statistics words are:
# 	theoretical (0.14903129657228018)
# 	variables (0.13214108296075508)
# 	estimation (0.15896671634376552)
# 	stochastic (0.13263785394932937)
# 	statistical (0.15350223546944858)
# 	distribution (0.18529557873820168)
# 	algorithm (0.3879781420765027)
# 	dimensional (0.18529557873820168)
# 	inference (0.1957277694982613)
# 	regression (0.16641828117237953)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3316627f-74ac-4592-8ab8-cd740d512278" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3316627f-74ac-4592-8ab8-cd740d512278")) {                    Plotly.newPlot(                        "3316627f-74ac-4592-8ab8-cd740d512278",                        [{"x":["similarity","distances","processes","aggregate","measuring","formulation","structure","reinforcement","discounted","bisimulation","approximators","extraction","smoothing","identifying","responses","consistency","electroencephalogram","developed","activated","associated","recognition","relatively","classification","investigated","systematically","efficiency","performance","stability","algorithms","different","investigate","significant","selection","experimental","incorporate","important","strengthen","heteroscedastic","variances","effective","estimation","demonstrate","including","algorithm","pointwise","typically","truncated","reduction","confidence","synthetic","theoretical","potential","effectiveness","optimization","guarantee","variational","framework","independent","unavailability","designated","requirements","conversion","representations","functions","comprises","reconstruct","practical","alignments","frameworks","applications","evaluations","objective","subjective","synthesizing","facilitates","correspondence","requirement","unaligned","construct","understanding","formalize","splitting","technique","functional","gradients","mathematically","attractive","viewpoint","leveraging","perspective","generalization","optimizing","combining","perception","guarantees","methodology","divergence","variables","relationships","explicitly","combination","propagation","distributions","illustrated","approximate","forecasting","observations","dynamically","developments","described","parameters","discussed","procedure","explanatory","necessarily","approximation","scenarios","application","considering","behavioral","decisions","propositions","propositional","membership","interpretable","interpretations","vehicular","multivalued","observables","possibilities","naturally","eigenvectors","processing","classical","braitenberg","represented","eigenvalues","operators","adjacency","consistent","blockmodel","simulated","geometric","overlapping","knowledge","stochastic","clustering","properties","logarithmic","communities","resulting","transform","incorporation","fundamental","challenging","inherently","representation","representative","granularities","vocabulary","inferring","information","nonparametric","congressional","retrieval","multilingual","introduced","evolution","deceptive","iterations","collaborations","parasites","evolutionary","additionally","evaluation","exponentially","symbiotic","magnitude","integration","techniques","automatically","principles","contributions","references","university","automatic","describes","literature","detection","evaluating","reciprocal","particular","citations","scientists","collaborate","advantage","introduces","phenomena","paraphrases","collaborative","efficient","perspectives","estimating","relaxation","structures","complements","establish","solutions","relaxations","sufficient","dimensional","idealized","improving","corollary","memberships","mechanism","correctly","generally","conditions","programming","integrality","semidefinite","separation","numerical","prototype","ingredient","sketching","consequently","multiplication","relationship","standpoint","substantially","extrapolation","addressing","bootstrap","dimension","computation","empirical","difficult","randomized","precisely","accelerates","computational","essential","computations","classifier","vulnerable","subnetwork","distinguishing","adversarial","specifically","tremendously","adversaries","perturbations" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pointwise
# 	corollary
# 	counteracts
# 	cumulants
# 	conformal
# 	variationally
# 	bivariate
# 	prespecified
# 	inhibited
# 	semiparametric
# 	blockmodels
# 	minibatches
# 	regulations
# 	recombine
# 	lightspeed
# 	inheriting
# 	nonconjugate
# 	embarrassingly
# 	projectorg
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	bisimulation
# 	propositions
# 	propositional
# 	vehicular
# 	multivalued
# 	braitenberg
# 	deceptive
# 	symbiotic
# 	citations
# 	collaborate
# 	paraphrases
# 	implausible
# 	enhancements
# 	photographic
# 	milliseconds
# 	neuromorphic
# 	memristive
# 	exclusion
# 	truncating
# 	traversability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081759068076058e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
